# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
import seaborn as sns

# %%
# Imported the Plant Protection Products data as a csv

PPP_Data = pd.read_csv(r'C:\Users\Mike\Desktop\PPP_Data_Project\PPP_Data.csv')

# %%
print(PPP_Data)
# Out:
#                               Company Name     Product Name  PCS No  \
# 0      Adama Agricultural Solutions UK Ltd    Afalon Liquid    2839
# 1      Adama Agricultural Solutions UK Ltd    Afalon Liquid    2839
# 2      Adama Agricultural Solutions UK Ltd    Afalon Liquid    4452
# 3      Adama Agricultural Solutions UK Ltd    Afalon Liquid    2839
# 4      Adama Agricultural Solutions UK Ltd    Afalon Liquid    2839
# ...                                    ...              ...     ...
# 20769             Whelehan Crop Protection  Whelehan Shield    4178
# 20770             Whelehan Crop Protection  Whelehan Shield    4178
# 20771             Whelehan Crop Protection  Whelehan Shield    4178
# 20772              Xeda International S.A.           Biox-M    5431
# 20773              Xeda International S.A.           Biox-M    5431
#
#                    CropCategory          Function                      Crop  \
# 0                        Pulses         Herbicide             Beans - field
# 1      Root and Tuber Vegetable         Herbicide                   Carrots
# 2               Stem Vegetables         Herbicide            Celery - field
# 3               Stem Vegetables         Herbicide            Celery - field
# 4               Stem Vegetables         Herbicide                    Fennel
# ...                         ...               ...                       ...
# 20769                   Cereals         Herbicide            Wheat - spring
# 20770                   Cereals         Herbicide            Wheat - winter
# 20771             Miscellaneous         Herbicide                    Willow
# 20772                  Potatoes  Growth Regulator  Potatoes - stored - ware
# 20773                  Potatoes  Growth Regulator  Potatoes - stored - ware
#
#                          Methodof Applic MaxIndividualDose     MaxTotalDose  \
# 0      Tractor Mounted / Trailed Sprayer         1.35 l/ha        1.35 l/ha
# 1      Tractor Mounted / Trailed Sprayer          2.1 l/ha         2.1 l/ha
# 2      Tractor Mounted / Trailed Sprayer         1.35 l/ha        1.35 l/ha
# 3      Tractor Mounted / Trailed Sprayer         1.35 l/ha        1.35 l/ha
# 4      Tractor Mounted / Trailed Sprayer         1.35 l/ha        1.35 l/ha
# ...                                  ...               ...              ...
# 20769  Tractor Mounted / Trailed Sprayer          0.7 l/ha         0.7 l/ha
# 20770  Tractor Mounted / Trailed Sprayer          0.7 l/ha         0.7 l/ha
# 20771  Tractor Mounted / Trailed Sprayer          2.0 l/ha         2.0 l/ha
# 20772                  Fogging Equipment    90ml per tonne  360ml per tonne
# 20773                         Applicator     2ml/tonne/day  360ml per tonne
#
#       MaxNoApplications                              Timing of Application  \
# 0                     -             After sowing but before crop emergence
# 1          1 or 2 split  Apply pre or post crop emergence. Max ind. dos...
# 2                     -                                                NaN
# 3                     -                                                NaN
# 4                     -                                                NaN
# ...                 ...                                                ...
# 20769                 -                                                NaN
# 20770                 -                                                NaN
# 20771               NaN                                                NaN
# 20772                10                                                NaN
# 20773                 -                                                NaN
#
#       Latest Time of Application      PHI  \
# 0          Pre-emergence of crop      NaN
# 1            90 days pre harvest  90 days
# 2         60 days before harvest  60 days
# 3         60 days before harvest  60 days
# 4         60 days before harvest  60 days
# ...                          ...      ...
# 20769               Before GS 33      NaN
# 20770               Before GS 33      NaN
# 20771                        NaN      NaN
# 20772                          -      NaN
# 20773                          -      NaN
#
#                                                Comments      Substance  \
# 0                                                   NaN        Linuron
# 1                                                   NaN        Linuron
# 2                                                   NaN        Linuron
# 3                                                   NaN        Linuron
# 4                                                   NaN        Linuron
# ...                                                 ...            ...
# 20769                                               NaN     Clopyralid
# 20770                                               NaN     Clopyralid
# 20771                                               NaN     Clopyralid
# 20772                                               NaN  Spearmint oil
# 20773  Cold evaporation method using Xedavap applicator  Spearmint oil
#
#         Content Registration revoked
# 0       450 g/l            03-Jun-17
# 1       450 g/l            03-Jun-17
# 2       450 g/l            15-Sep-11
# 3       450 g/l            03-Jun-17
# 4       450 g/l            03-Jun-17
# ...         ...                  ...
# 20769   100 g/l            19-May-12
# 20770   100 g/l            19-May-12
# 20771   100 g/l            19-May-12
# 20772  100% w/w                  NaN
# 20773  100% w/w                  NaN
#
# [20774 rows x 17 columns]

# %%
PPP_Data.head()
# Out:
#                           Company Name   Product Name  PCS No  \
# 0  Adama Agricultural Solutions UK Ltd  Afalon Liquid    2839
# 1  Adama Agricultural Solutions UK Ltd  Afalon Liquid    2839
# 2  Adama Agricultural Solutions UK Ltd  Afalon Liquid    4452
# 3  Adama Agricultural Solutions UK Ltd  Afalon Liquid    2839
# 4  Adama Agricultural Solutions UK Ltd  Afalon Liquid    2839
#
#                CropCategory   Function            Crop  \
# 0                    Pulses  Herbicide   Beans - field
# 1  Root and Tuber Vegetable  Herbicide         Carrots
# 2           Stem Vegetables  Herbicide  Celery - field
# 3           Stem Vegetables  Herbicide  Celery - field
# 4           Stem Vegetables  Herbicide          Fennel
#
#                      Methodof Applic MaxIndividualDose MaxTotalDose  \
# 0  Tractor Mounted / Trailed Sprayer         1.35 l/ha    1.35 l/ha
# 1  Tractor Mounted / Trailed Sprayer          2.1 l/ha     2.1 l/ha
# 2  Tractor Mounted / Trailed Sprayer         1.35 l/ha    1.35 l/ha
# 3  Tractor Mounted / Trailed Sprayer         1.35 l/ha    1.35 l/ha
# 4  Tractor Mounted / Trailed Sprayer         1.35 l/ha    1.35 l/ha
#
#   MaxNoApplications                              Timing of Application  \
# 0                 -             After sowing but before crop emergence
# 1      1 or 2 split  Apply pre or post crop emergence. Max ind. dos...
# 2                 -                                                NaN
# 3                 -                                                NaN
# 4                 -                                                NaN
#
#   Latest Time of Application      PHI Comments Substance  Content  \
# 0      Pre-emergence of crop      NaN      NaN   Linuron  450 g/l
# 1        90 days pre harvest  90 days      NaN   Linuron  450 g/l
# 2     60 days before harvest  60 days      NaN   Linuron  450 g/l
# 3     60 days before harvest  60 days      NaN   Linuron  450 g/l
# 4     60 days before harvest  60 days      NaN   Linuron  450 g/l
#
#   Registration revoked
# 0            03-Jun-17
# 1            03-Jun-17
# 2            15-Sep-11
# 3            03-Jun-17
# 4            03-Jun-17

# %%
PPP_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20774 entries, 0 to 20773
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Company Name                20774 non-null  object
#  1   Product Name                20774 non-null  object
#  2   PCS No                      20774 non-null  int64
#  3   CropCategory                20774 non-null  object
#  4   Function                    20774 non-null  object
#  5   Crop                        20774 non-null  object
#  6   Methodof Applic             20774 non-null  object
#  7   MaxIndividualDose           20404 non-null  object
#  8   MaxTotalDose                19683 non-null  object
#  9   MaxNoApplications           18973 non-null  object
#  10  Timing of Application       6190 non-null   object
#  11  Latest Time of Application  18375 non-null  object
#  12  PHI                         5317 non-null   object
#  13  Comments                    1972 non-null   object
#  14  Substance                   20774 non-null  object
#  15  Content                     20774 non-null  object
#  16  Registration revoked        11229 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 2.7+ MB

# %%
PPP_Data.index
# Out:
# RangeIndex(start=0, stop=20774, step=1)

# %%
PPP_Data.dtypes
# Out:
# Company Name                  object
# Product Name                  object
# PCS No                         int64
# CropCategory                  object
# Function                      object
# Crop                          object
# Methodof Applic               object
# MaxIndividualDose             object
# MaxTotalDose                  object
# MaxNoApplications             object
# Timing of Application         object
# Latest Time of Application    object
# PHI                           object
# Comments                      object
# Substance                     object
# Content                       object
# Registration revoked          object
# dtype: object

# %%
# Pulled out Function Column

PPP_Data['Function']
# Out:
# 0               Herbicide
# 1               Herbicide
# 2               Herbicide
# 3               Herbicide
# 4               Herbicide
#                ...
# 20769           Herbicide
# 20770           Herbicide
# 20771           Herbicide
# 20772    Growth Regulator
# 20773    Growth Regulator
# Name: Function, Length: 20774, dtype: object

# %%
# Pull out 2 columns for comparison

PPP_Data[['Function', 'Substance']]
# Out:
#                Function      Substance
# 0             Herbicide        Linuron
# 1             Herbicide        Linuron
# 2             Herbicide        Linuron
# 3             Herbicide        Linuron
# 4             Herbicide        Linuron
# ...                 ...            ...
# 20769         Herbicide     Clopyralid
# 20770         Herbicide     Clopyralid
# 20771         Herbicide     Clopyralid
# 20772  Growth Regulator  Spearmint oil
# 20773  Growth Regulator  Spearmint oil
#
# [20774 rows x 2 columns]

# %%
# checking to see what columns are missing information, used this info to guide my future comparisons.

PPP_Data.isnull().sum()
# Out:
# Company Name                      0
# Product Name                      0
# PCS No                            0
# CropCategory                      0
# Function                          0
# Crop                              0
# Methodof Applic                   0
# MaxIndividualDose               370
# MaxTotalDose                   1091
# MaxNoApplications              1801
# Timing of Application         14584
# Latest Time of Application     2399
# PHI                           15457
# Comments                      18802
# Substance                         0
# Content                           0
# Registration revoked           9545
# dtype: int64

# %%
PPP_Data.iloc[9524:20773]
# Out:
#                    Company Name     Product Name  PCS No  \
# 9524       Dow AgroSciences Ltd      Pastor Trio    5808
# 9525       Dow AgroSciences Ltd      Pastor Trio    5808
# 9526       Dow AgroSciences Ltd      Pastor Trio    5808
# 9527       Dow AgroSciences Ltd      Pastor Trio    5808
# 9528       Dow AgroSciences Ltd      Pastor Trio    5808
# ...                         ...              ...     ...
# 20768  Whelehan Crop Protection  Whelehan Shield    4178
# 20769  Whelehan Crop Protection  Whelehan Shield    4178
# 20770  Whelehan Crop Protection  Whelehan Shield    4178
# 20771  Whelehan Crop Protection  Whelehan Shield    4178
# 20772   Xeda International S.A.           Biox-M    5431
#
#                    CropCategory          Function                      Crop  \
# 9524                    Cereals         Herbicide           Barley - spring
# 9525                    Cereals         Herbicide           Barley - winter
# 9526                    Cereals         Herbicide           Barley - winter
# 9527                    Cereals         Herbicide           Barley - winter
# 9528                  Grassland         Herbicide   Grassland - established
# ...                         ...               ...                       ...
# 20768  Root and Tuber Vegetable         Herbicide                    Turnip
# 20769                   Cereals         Herbicide            Wheat - spring
# 20770                   Cereals         Herbicide            Wheat - winter
# 20771             Miscellaneous         Herbicide                    Willow
# 20772                  Potatoes  Growth Regulator  Potatoes - stored - ware
#
#                          Methodof Applic MaxIndividualDose     MaxTotalDose  \
# 9524   Tractor Mounted / Trailed Sprayer          1.0 l/ha         1.0 l/ha
# 9525   Tractor Mounted / Trailed Sprayer          1.0 l/ha         1.0 l/ha
# 9526   Tractor Mounted / Trailed Sprayer          1.0 l/ha         1.0 l/ha
# 9527   Tractor Mounted / Trailed Sprayer          1.0 l/ha         1.0 l/ha
# 9528   Tractor Mounted / Trailed Sprayer          2.0 l/ha         2.0 l/ha
# ...                                  ...               ...              ...
# 20768  Tractor Mounted / Trailed Sprayer          2.0 l/ha         3.0 l/ha
# 20769  Tractor Mounted / Trailed Sprayer          0.7 l/ha         0.7 l/ha
# 20770  Tractor Mounted / Trailed Sprayer          0.7 l/ha         0.7 l/ha
# 20771  Tractor Mounted / Trailed Sprayer          2.0 l/ha         2.0 l/ha
# 20772                  Fogging Equipment    90ml per tonne  360ml per tonne
#
#       MaxNoApplications Timing of Application  \
# 9524         1 per year    After 1st February
# 9525         1 per year    After 1st February
# 9526         1 per year    After 1st February
# 9527         1 per year    After 1st February
# 9528         1 per year    After 1st February
# ...                 ...                   ...
# 20768                 -                   NaN
# 20769                 -                   NaN
# 20770                 -                   NaN
# 20771               NaN                   NaN
# 20772                10                   NaN
#
#                       Latest Time of Application      PHI  \
# 9524                                Before GS 39      NaN
# 9525                                Before GS 39      NaN
# 9526                                Before GS 39      NaN
# 9527                                Before GS 39      NaN
# 9528   30th Sept & 7 days before cutting/grazing      NaN
# ...                                          ...      ...
# 20768                     6 weeks before harvest  6 weeks
# 20769                               Before GS 33      NaN
# 20770                               Before GS 33      NaN
# 20771                                        NaN      NaN
# 20772                                          -      NaN
#
#                                                 Comments      Substance  \
# 9524   The total amount of florasulam applied to a ce...     Clopyralid
# 9525   The total amount of florasulam applied to a ce...     Clopyralid
# 9526   The total amount of florasulam applied to a ce...     Fluroxypyr
# 9527   The total amount of florasulam applied to a ce...     Florasulam
# 9528                                                 NaN     Fluroxypyr
# ...                                                  ...            ...
# 20768                                                NaN     Clopyralid
# 20769                                                NaN     Clopyralid
# 20770                                                NaN     Clopyralid
# 20771                                                NaN     Clopyralid
# 20772                                                NaN  Spearmint oil
#
#         Content Registration revoked
# 9524     80 g/l                  NaN
# 9525     80 g/l                  NaN
# 9526    100 g/l                  NaN
# 9527    2.5 g/l                  NaN
# 9528    100 g/l                  NaN
# ...         ...                  ...
# 20768   100 g/l            19-May-12
# 20769   100 g/l            19-May-12
# 20770   100 g/l            19-May-12
# 20771   100 g/l            19-May-12
# 20772  100% w/w                  NaN
#
# [11249 rows x 17 columns]

# %%
PPP_Data.iloc[0:9523]
# Out:
#                              Company Name   Product Name  PCS No  \
# 0     Adama Agricultural Solutions UK Ltd  Afalon Liquid    2839
# 1     Adama Agricultural Solutions UK Ltd  Afalon Liquid    2839
# 2     Adama Agricultural Solutions UK Ltd  Afalon Liquid    4452
# 3     Adama Agricultural Solutions UK Ltd  Afalon Liquid    2839
# 4     Adama Agricultural Solutions UK Ltd  Afalon Liquid    2839
# ...                                   ...            ...     ...
# 9518                 Dow AgroSciences Ltd         Pastor     766
# 9519                 Dow AgroSciences Ltd     Pastor Pro    5287
# 9520                 Dow AgroSciences Ltd     Pastor Pro    5287
# 9521                 Dow AgroSciences Ltd     Pastor Pro    5287
# 9522                 Dow AgroSciences Ltd    Pastor Trio    5808
#
#                   CropCategory   Function                          Crop  \
# 0                       Pulses  Herbicide                 Beans - field
# 1     Root and Tuber Vegetable  Herbicide                       Carrots
# 2              Stem Vegetables  Herbicide                Celery - field
# 3              Stem Vegetables  Herbicide                Celery - field
# 4              Stem Vegetables  Herbicide                        Fennel
# ...                        ...        ...                           ...
# 9518                  Non-Crop  Herbicide  Non Crop - permeable surface
# 9519                 Grassland  Herbicide       Grassland - established
# 9520                 Grassland  Herbicide       Grassland - established
# 9521                 Grassland  Herbicide       Grassland - established
# 9522                   Cereals  Herbicide               Barley - spring
#
#                         Methodof Applic MaxIndividualDose MaxTotalDose  \
# 0     Tractor Mounted / Trailed Sprayer         1.35 l/ha    1.35 l/ha
# 1     Tractor Mounted / Trailed Sprayer          2.1 l/ha     2.1 l/ha
# 2     Tractor Mounted / Trailed Sprayer         1.35 l/ha    1.35 l/ha
# 3     Tractor Mounted / Trailed Sprayer         1.35 l/ha    1.35 l/ha
# 4     Tractor Mounted / Trailed Sprayer         1.35 l/ha    1.35 l/ha
# ...                                 ...               ...          ...
# 9518  Tractor Mounted / Trailed Sprayer          4.0 l/ha     4.0 l/ha
# 9519  Tractor Mounted / Trailed Sprayer          4.0 l/ha     4.0 l/ha
# 9520  Tractor Mounted / Trailed Sprayer          4.0 l/ha     4.0 l/ha
# 9521  Tractor Mounted / Trailed Sprayer          4.0 l/ha     4.0 l/ha
# 9522  Tractor Mounted / Trailed Sprayer          1.0 l/ha     1.0 l/ha
#
#                       MaxNoApplications  \
# 0                                     -
# 1                          1 or 2 split
# 2                                     -
# 3                                     -
# 4                                     -
# ...                                 ...
# 9518  2 ( 1 x 4.0 l/ha or 2 x 2.0 l/ha)
# 9519                                  -
# 9520                                  -
# 9521                                  -
# 9522                         1 per year
#
#                                   Timing of Application  \
# 0                After sowing but before crop emergence
# 1     Apply pre or post crop emergence. Max ind. dos...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9518  Single: spring/ autumn depending on weeds pres...
# 9519                 Between 1st March and 31st October
# 9520                 Between 1st March and 31st October
# 9521                 Between 1st March and 31st October
# 9522                                 After 1st February
#
#                Latest Time of Application      PHI  \
# 0                   Pre-emergence of crop      NaN
# 1                     90 days pre harvest  90 days
# 2                  60 days before harvest  60 days
# 3                  60 days before harvest  60 days
# 4                  60 days before harvest  60 days
# ...                                   ...      ...
# 9518                                  NaN      NaN
# 9519  7 days before harvesting or grazing      NaN
# 9520  7 days before harvesting or grazing      NaN
# 9521  7 days before harvesting or grazing      NaN
# 9522                         Before GS 39      NaN
#
#                                                Comments   Substance  Content  \
# 0                                                   NaN     Linuron  450 g/l
# 1                                                   NaN     Linuron  450 g/l
# 2                                                   NaN     Linuron  450 g/l
# 3                                                   NaN     Linuron  450 g/l
# 4                                                   NaN     Linuron  450 g/l
# ...                                                 ...         ...      ...
# 9518            Do not apply on sports or amenity turf.   Triclopyr  100 g/l
# 9519                                                NaN  Clopyralid   50 g/l
# 9520                                                NaN  Fluroxypyr   75 g/l
# 9521                                                NaN   Triclopyr  100 g/l
# 9522  The total amount of florasulam applied to a ce...  Fluroxypyr  100 g/l
#
#      Registration revoked
# 0               03-Jun-17
# 1               03-Jun-17
# 2               15-Sep-11
# 3               03-Jun-17
# 4               03-Jun-17
# ...                   ...
# 9518            31-Dec-12
# 9519            30-Sep-16
# 9520            30-Sep-16
# 9521            30-Sep-16
# 9522                  NaN
#
# [9523 rows x 17 columns]

# %%
PPP_Data.columns = PPP_Data.columns.str.replace(' ','_')

# %%
PPP_Data.head()
# Out:
#                           Company_Name   Product_Name  PCS_No  \
# 0  Adama Agricultural Solutions UK Ltd  Afalon Liquid    2839
# 1  Adama Agricultural Solutions UK Ltd  Afalon Liquid    2839
# 2  Adama Agricultural Solutions UK Ltd  Afalon Liquid    4452
# 3  Adama Agricultural Solutions UK Ltd  Afalon Liquid    2839
# 4  Adama Agricultural Solutions UK Ltd  Afalon Liquid    2839
#
#                CropCategory   Function            Crop  \
# 0                    Pulses  Herbicide   Beans - field
# 1  Root and Tuber Vegetable  Herbicide         Carrots
# 2           Stem Vegetables  Herbicide  Celery - field
# 3           Stem Vegetables  Herbicide  Celery - field
# 4           Stem Vegetables  Herbicide          Fennel
#
#                      Methodof_Applic MaxIndividualDose MaxTotalDose  \
# 0  Tractor Mounted / Trailed Sprayer         1.35 l/ha    1.35 l/ha
# 1  Tractor Mounted / Trailed Sprayer          2.1 l/ha     2.1 l/ha
# 2  Tractor Mounted / Trailed Sprayer         1.35 l/ha    1.35 l/ha
# 3  Tractor Mounted / Trailed Sprayer         1.35 l/ha    1.35 l/ha
# 4  Tractor Mounted / Trailed Sprayer         1.35 l/ha    1.35 l/ha
#
#   MaxNoApplications                              Timing_of_Application  \
# 0                 -             After sowing but before crop emergence
# 1      1 or 2 split  Apply pre or post crop emergence. Max ind. dos...
# 2                 -                                                NaN
# 3                 -                                                NaN
# 4                 -                                                NaN
#
#   Latest_Time_of_Application      PHI Comments Substance  Content  \
# 0      Pre-emergence of crop      NaN      NaN   Linuron  450 g/l
# 1        90 days pre harvest  90 days      NaN   Linuron  450 g/l
# 2     60 days before harvest  60 days      NaN   Linuron  450 g/l
# 3     60 days before harvest  60 days      NaN   Linuron  450 g/l
# 4     60 days before harvest  60 days      NaN   Linuron  450 g/l
#
#   Registration_revoked
# 0            03-Jun-17
# 1            03-Jun-17
# 2            15-Sep-11
# 3            03-Jun-17
# 4            03-Jun-17

# %%
PPP_short = pd.DataFrame(PPP_Data, columns = ['Function', 'Substance'])

# %%
PPP_short.head()
# Out:
#     Function Substance
# 0  Herbicide   Linuron
# 1  Herbicide   Linuron
# 2  Herbicide   Linuron
# 3  Herbicide   Linuron
# 4  Herbicide   Linuron

# %%
PPP_short.isnull().sum()
# Out:
# Function     0
# Substance    0
# dtype: int64

# %%
PPP_short.groupby(['Function']).groups.keys()
# Out:
# dict_keys(['Acaricide', 'Acaricide/Insecticide', 'Adjuvant', 'Antioxidant', 'Attractant', 'Bactericide', 'Disinfectant', 'Fumigant', 'Fungicide', 'Growth Regulator', 'Growth Regulator/Fungicide', 'Herbicide', 'Insecticide', 'Miscellaneous', 'Molluscicide', 'Nematicide', 'Repellant', 'Seed Dressing', 'Sterilant'])

# %%
pd.DataFrame(PPP_short)
# Out:
#                Function      Substance
# 0             Herbicide        Linuron
# 1             Herbicide        Linuron
# 2             Herbicide        Linuron
# 3             Herbicide        Linuron
# 4             Herbicide        Linuron
# ...                 ...            ...
# 20769         Herbicide     Clopyralid
# 20770         Herbicide     Clopyralid
# 20771         Herbicide     Clopyralid
# 20772  Growth Regulator  Spearmint oil
# 20773  Growth Regulator  Spearmint oil
#
# [20774 rows x 2 columns]

# %%
PPP_short.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20774 entries, 0 to 20773
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Function   20774 non-null  object
#  1   Substance  20774 non-null  object
# dtypes: object(2)
# memory usage: 324.7+ KB

# %%
PPP_short.index
# Out:
# RangeIndex(start=0, stop=20774, step=1)

# %%
PPP_short.describe
# Out:
# <bound method NDFrame.describe of                Function      Substance
# 0             Herbicide        Linuron
# 1             Herbicide        Linuron
# 2             Herbicide        Linuron
# 3             Herbicide        Linuron
# 4             Herbicide        Linuron
# ...                 ...            ...
# 20769         Herbicide     Clopyralid
# 20770         Herbicide     Clopyralid
# 20771         Herbicide     Clopyralid
# 20772  Growth Regulator  Spearmint oil
# 20773  Growth Regulator  Spearmint oil
#
# [20774 rows x 2 columns]>

# %%
# Determining the types of products and number of substances associated with each product type, i.e. a herbicide is a product type and substance refers to the active substance which acts as a herbicide

PPP_short.groupby('Function', sort = False).count()
# Out:
#                             Substance
# Function
# Herbicide                        8596
# Insecticide                      2713
# Acaricide                          46
# Fungicide                        8059
# Molluscicide                      281
# Growth Regulator                  570
# Seed Dressing                     370
# Nematicide                         53
# Attractant                          8
# Adjuvant                           30
# Antioxidant                         2
# Fumigant                           20
# Miscellaneous                       2
# Sterilant                           2
# Repellant                           2
# Bactericide                         1
# Disinfectant                        3
# Acaricide/Insecticide              14
# Growth Regulator/Fungicide          2

# %%
PPP_short.groupby('Substance', sort = False).count()
# Out:
#                   Function
# Substance
# Linuron                 63
# Bromoxynil             121
# Pendimethalin          505
# Pirimicarb              64
# Clofentezine            24
# ...                    ...
# Maneb                    5
# Napropamide             40
# Gibberellic acid         3
# Nicotine                25
# Spearmint oil            2
#
# [284 rows x 1 columns]

# %%
print(PPP_short)
# Out:
#                Function      Substance
# 0             Herbicide        Linuron
# 1             Herbicide        Linuron
# 2             Herbicide        Linuron
# 3             Herbicide        Linuron
# 4             Herbicide        Linuron
# ...                 ...            ...
# 20769         Herbicide     Clopyralid
# 20770         Herbicide     Clopyralid
# 20771         Herbicide     Clopyralid
# 20772  Growth Regulator  Spearmint oil
# 20773  Growth Regulator  Spearmint oil
#
# [20774 rows x 2 columns]

# %%
PPP_short.columns
# Out:
# Index(['Function', 'Substance'], dtype='object')

# %%
PPP_short.shape
# Out:
# (20774, 2)

# %%
# example of poor graph choice

plt.scatter(PPP_short['Function'], PPP_short['Substance'], s = 2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Scatter plot example, again unsuitable

sns.scatterplot(x='Function',y='Substance', data=PPP_short,)
# Out:
# <AxesSubplot:xlabel='Function', ylabel='Substance'>

# %%
plt.bar('Function', 'Substance', data = PPP_short)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.barh('Function', 'Substance', data = PPP_short)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import seaborn as sns

# %%
sns.histplot(data=PPP_short, y='Function', x='Substance')
# Out:
# <AxesSubplot:xlabel='Substance', ylabel='Function'>
